# %% [markdown]
# # Exploring Simulated Data Products
#
# The purpose of this notebook is to explore the simulated event lightcurves and parameter sets generated by Anibal Verala.

# %%
from os import path, getcwd
from sys import path as pythonpath
pythonpath.append(path.join(getcwd(), '..'))
import utils

# %% [markdown]
# The test_data directory contains examples of Anibal's data, so lets load one of those files using the read_data routine from his package.

# %%
event_file = path.join(getcwd(), '..', 'test_data', 'Event_18.h5')

info_dataset, pyLIMA_parameters, phot_data = utils.read_data(event_file)

print(info_dataset)
print(pyLIMA_parameters)
print(phot_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 event_file = path.join(getcwd(), '..', 'test_data', 'Event_18.h5')
# ----> 3 info_dataset, pyLIMA_parameters, phot_data = utils.read_data(event_file)
#       5 print(info_dataset)
#       6 print(pyLIMA_parameters)
#
# File /data/software/roman_rubin_sim/notebooks/../utils.py:16, in read_data(path_model)
#      14 bands = {}
#      15 for band in ("W149", "u", "g", "r", "i", "z", "y"):
# ---> 16     loaded_table = QTable()
#      17     for col in file[band]:
#      18         loaded_table[col] = file[band][col][:]
#
# NameError: name 'QTable' is not defined
